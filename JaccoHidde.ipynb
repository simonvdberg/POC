# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
datasource = pd.read_excel('data/datamaandagavond.xlsx')
datasource
# Out:
#             nr  PC4_LEERL  KWALIFICATIENIVEAU  KWALIFICATIE CODE  \
# 0         1387       1011                   1              25251
# 1         1388       1011                   1              25257
# 2         1389       1011                   1              90440
# 3         1390       1011                   1              90440
# 4         1391       1011                   1              91444
# 5         1392       1011                   2              90252
# 6         1393       1011                   2              90472
# 7         1394       1011                   2              90760
# 8         1395       1011                   2              90871
# 9         1396       1011                   2              91450
# 10        1397       1011                   2              92640
# 11        1398       1011                   2              92640
# 12        1399       1011                   2              93751
# ...

# %%
datasource.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396434 entries, 0 to 396433
# Data columns (total 14 columns):
# nr                    396434 non-null int64
# PC4_LEERL             396434 non-null int64
# KWALIFICATIENIVEAU    396434 non-null int64
# KWALIFICATIE CODE     396434 non-null int64
# KWALIFICATIE NAAM     396434 non-null object
# MBO SECTOR            396434 non-null object
# DOMEIN                396434 non-null object
# SECTORUNIT SBB        396434 non-null object
# GESLACHT              396434 non-null object
# 2013   AANT           396434 non-null int64
# 2014   AANT           396434 non-null int64
# 2015   AANT           396434 non-null int64
# 2016   AANT           396434 non-null int64
# 2017   AANT           396434 non-null int64
# dtypes: int64(9), object(5)
# memory usage: 42.3+ MB

# %%
koppeltabel = pd.read_excel("data/PC4.xlsx")
koppeltabel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4307 entries, 0 to 4306
# Data columns (total 9 columns):
# PC4                 4307 non-null int64
# Woonplaatscode      4307 non-null int64
# Woonplaats          4307 non-null object
# Gemeentecode        4307 non-null int64
# Gemeente            4307 non-null object
# Provincie           4307 non-null object
# Veiligheidsregio    4307 non-null object
# Politie-eenheid     4307 non-null object
# Omgevingsdienst     4307 non-null object
# dtypes: int64(3), object(6)
# memory usage: 302.9+ KB

# %%
koppeltabel
# Out:
#        PC4  Woonplaatscode                Woonplaats  Gemeentecode  \
# 0     9446            1147                      Amen          1680
# 1     9465            1148                   Anderen          1680
# 2     9467            1149                     Anloo          1680
# 3     9468            1150                     Annen          1680
# 4     9654            1151       Annerveenschekanaal          1680
# 5     9459            1153               Balloërveld          1680
# 6     9458            1152                    Balloo          1680
# 7     9457            1154                    Deurze          1680
# 8     9463            1155                      Eext          1680
# 9     9658            1156                Eexterveen          1680
# 10    9659            1157      Eexterveenschekanaal          1680
# 11    9464            1158           Eexterzandvoort          1680
# 12    9454            1159                   Ekehaar          1680
# ...

# %%
test123 = datasource.rename(columns={'PC4_LEERL': 'PC4', '2013   AANT': '2013','2014   AANT': '2014','2015   AANT': '2015','2016   AANT': '2016','2017   AANT': '2017'})
test123.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396434 entries, 0 to 396433
# Data columns (total 14 columns):
# nr                    396434 non-null int64
# PC4                   396434 non-null int64
# KWALIFICATIENIVEAU    396434 non-null int64
# KWALIFICATIE CODE     396434 non-null int64
# KWALIFICATIE NAAM     396434 non-null object
# MBO SECTOR            396434 non-null object
# DOMEIN                396434 non-null object
# SECTORUNIT SBB        396434 non-null object
# GESLACHT              396434 non-null object
# 2013                  396434 non-null int64
# 2014                  396434 non-null int64
# 2015                  396434 non-null int64
# 2016                  396434 non-null int64
# 2017                  396434 non-null int64
# dtypes: int64(9), object(5)
# memory usage: 42.3+ MB

# %%
output = pd.merge(test123, koppeltabel, on='PC4', how='inner')
output.head(100)
# Out:
#       nr   PC4  KWALIFICATIENIVEAU  KWALIFICATIE CODE  \
# 0   1387  1011                   1              25251
# 1   1388  1011                   1              25257
# 2   1389  1011                   1              90440
# 3   1390  1011                   1              90440
# 4   1391  1011                   1              91444
# 5   1392  1011                   2              90252
# 6   1393  1011                   2              90472
# 7   1394  1011                   2              90760
# 8   1395  1011                   2              90871
# 9   1396  1011                   2              91450
# 10  1397  1011                   2              92640
# 11  1398  1011                   2              92640
# 12  1399  1011                   2              93751
# 13  1400  1011                   2              93751
# 14  1401  1011                   2              94110
# 15  1402  1011                   2              94140
# ...

# %%
output["optel"] = output["2013"] + output["2014"] + output["2015"] + output["2016"] + output["2017"]
output
# Out:
#             nr   PC4  KWALIFICATIENIVEAU  KWALIFICATIE CODE  \
# 0         1387  1011                   1              25251
# 1         1388  1011                   1              25257
# 2         1389  1011                   1              90440
# 3         1390  1011                   1              90440
# 4         1391  1011                   1              91444
# 5         1392  1011                   2              90252
# 6         1393  1011                   2              90472
# 7         1394  1011                   2              90760
# 8         1395  1011                   2              90871
# 9         1396  1011                   2              91450
# 10        1397  1011                   2              92640
# 11        1398  1011                   2              92640
# 12        1399  1011                   2              93751
# 13        1400  1011                   2              93751
# 14        1401  1011                   2              94110
# ...

# %%
output.MBO4 = output.loc[(output['KWALIFICATIENIVEAU']== 4)]
output.MBO4
# Out:
#             nr   PC4  KWALIFICATIENIVEAU  KWALIFICATIE CODE  \
# 37        1424  1011                   4              10388
# 38        1425  1011                   4              10801
# 39        1426  1011                   4              90038
# 40        1427  1011                   4              90290
# 41        1428  1011                   4              90301
# 42        1429  1011                   4              90301
# 43        1430  1011                   4              90303
# 44        1431  1011                   4              90303
# 45        1432  1011                   4              90411
# 46        1433  1011                   4              90412
# 47        1434  1011                   4              90413
# 48        1435  1011                   4              90414
# 49        1436  1011                   4              90531
# 50        1437  1011                   4              90532
# 51        1438  1011                   4              90534
# ...

# %%
from seaborn import countplot
from matplotlib.pyplot import figure, show
# %config IPCompleter.greedy = True  
# %matplotlib inline
figure(figsize=(70,20))
countplot(data=output.MBO4, x = "DOMEIN")
show()
